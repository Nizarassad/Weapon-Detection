# %% [markdown]
# Note: here are the links to see the results of each training session, conducted during this study of training yolov8s on custom dataset for gun detection:
# - Training 1: https://app.clear.ml/projects/9aa9aa60ac6a4896ba8d1b6c137540d5/experiments/51f7987d37e54c58b1b117a11c90fa39/output/execution
# - Training 2: https://app.clear.ml/projects/9aa9aa60ac6a4896ba8d1b6c137540d5/experiments/2fc6c6f30f184f6dbe0d2e71b3fba1b4/output/execution
# - Training 3: https://app.clear.ml/projects/9aa9aa60ac6a4896ba8d1b6c137540d5/experiments/8272f5bc530a41e281a45e3e18447083/output/execution
# - Training 4: https://app.clear.ml/projects/9aa9aa60ac6a4896ba8d1b6c137540d5/experiments/531bb5a9bff64562bd150e2124178d58/output/execution
# - Training 5: https://app.clear.ml/projects/9aa9aa60ac6a4896ba8d1b6c137540d5/experiments/10940d6a01a34141abeb256c3f5c375a/output/execution

# %%
# Setting our content directory as HOME
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# Pip install method, and importing ultralytics
# !pip install ultralytics==8.0.20
from IPython import display
display.clear_output()
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 27.0/78.2 GB disk)

# %%
# Importing  libraries for weight and training and evaluation scripts provided by ultralytics
from ultralytics import YOLO
from IPython.display import display, Image

# %%
# Downloading the dataset from Roboflow
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# %%
# !pip install roboflow
from roboflow import Roboflow
rf = Roboflow(api_key="HA6CUY3Vdt1sRtv6vmzQ")
project = rf.workspace("nizar-assad").project("pistols-lhjbh")
dataset = project.version(1645).download("yolov8")
# Out:
# WARNING: Ignoring invalid distribution -illow (c:\users\assad\desktop\weapon detection\venv\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\assad\desktop\weapon detection\venv\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\assad\desktop\weapon detection\venv\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\assad\desktop\weapon detection\venv\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\assad\desktop\weapon detection\venv\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\assad\desktop\weapon detection\venv\lib\site-packages)
# WARNING: You are using pip version 22.0.4; however, version 23.3.1 is available.
# You should consider upgrading via the 'C:\Users\assad\Desktop\weapon detection\venv\Scripts\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: roboflow in c:\users\assad\desktop\weapon detection\venv\lib\site-packages (1.1.9)
# Requirement already satisfied: python-dateutil in c:\users\assad\desktop\weapon detection\venv\lib\site-packages (from roboflow) (2.8.2)
# Requirement already satisfied: urllib3>=1.26.6 in c:\users\assad\desktop\weapon detection\venv\lib\site-packages (from roboflow) (2.0.7)
# Requirement already satisfied: chardet==4.0.0 in c:\users\assad\desktop\weapon detection\venv\lib\site-packages (from roboflow) (4.0.0)
# Requirement already satisfied: matplotlib in c:\users\assad\desktop\weapon detection\venv\lib\site-packages (from roboflow) (3.8.1)
# Requirement already satisfied: six in c:\users\assad\desktop\weapon detection\venv\lib\site-packages (from roboflow) (1.16.0)
# Requirement already satisfied: opencv-python-headless==4.8.0.74 in c:\users\assad\desktop\weapon detection\venv\lib\site-packages (from roboflow) (4.8.0.74)
# Requirement already satisfied: cycler==0.10.0 in c:\users\assad\desktop\weapon detection\venv\lib\site-packages (from roboflow) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\assad\desktop\weapon detection\venv\lib\site-packages (from roboflow) (1.4.5)
# Requirement already satisfied: Pillow>=7.1.2 in c:\users\assad\desktop\weapon detection\venv\lib\site-packages (from roboflow) (10.0.1)
# Requirement already satisfied: requests-toolbelt in c:\users\assad\desktop\weapon detection\venv\lib\site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: requests in c:\users\assad\desktop\weapon detection\venv\lib\site-packages (from roboflow) (2.31.0)
# Requirement already satisfied: pyparsing==2.4.7 in c:\users\assad\desktop\weapon detection\venv\lib\site-packages (from roboflow) (2.4.7)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\assad\desktop\weapon detection\venv\lib\site-packages (from roboflow) (1.26.1)
# Requirement already satisfied: idna==2.10 in c:\users\assad\desktop\weapon detection\venv\lib\site-packages (from roboflow) (2.10)
# Requirement already satisfied: certifi==2023.7.22 in c:\users\assad\desktop\weapon detection\venv\lib\site-packages (from roboflow) (2023.7.22)
# Requirement already satisfied: python-dotenv in c:\users\assad\desktop\weapon detection\venv\lib\site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: tqdm>=4.41.0 in c:\users\assad\desktop\weapon detection\venv\lib\site-packages (from roboflow) (4.66.1)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\assad\desktop\weapon detection\venv\lib\site-packages (from roboflow) (6.0.1)
# Requirement already satisfied: supervision in c:\users\assad\desktop\weapon detection\venv\lib\site-packages (from roboflow) (0.16.0)
# Requirement already satisfied: python-magic in c:\users\assad\desktop\weapon detection\venv\lib\site-packages (from roboflow) (0.4.27)
# Requirement already satisfied: colorama in c:\users\assad\desktop\weapon detection\venv\lib\site-packages (from tqdm>=4.41.0->roboflow) (0.4.6)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\assad\desktop\weapon detection\venv\lib\site-packages (from matplotlib->roboflow) (6.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\assad\desktop\weapon detection\venv\lib\site-packages (from matplotlib->roboflow) (1.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\assad\desktop\weapon detection\venv\lib\site-packages (from matplotlib->roboflow) (23.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\assad\desktop\weapon detection\venv\lib\site-packages (from matplotlib->roboflow) (4.44.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\assad\desktop\weapon detection\venv\lib\site-packages (from requests->roboflow) (3.3.2)
# Requirement already satisfied: scipy<2.0.0,>=1.9.0 in c:\users\assad\desktop\weapon detection\venv\lib\site-packages (from supervision->roboflow) (1.11.3)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\assad\desktop\weapon detection\venv\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->roboflow) (3.17.0)
# loading Roboflow workspace...
# loading Roboflow project...
# [WARNING] we noticed you are downloading a `yolov8` datasets but you don't have `ultralytics` installed. Roboflow `.deploy` supports only models trained with `ultralytics==8.0.196`, to intall it `pip install ultralytics==8.0.196`.
# Downloading Dataset Version Zip in Pistols-1645 to yolov8:: 100%|██████████| 374175/374175 [01:10<00:00, 5271.40it/s]
# Extracting Dataset Version Zip to Pistols-1645 in yolov8:: 100%|██████████| 12321/12321 [00:07<00:00, 1729.12it/s]

# %% [markdown]
# ## Custom Training

# %% [markdown]
# We will install and initialize ClearML for assessing the trainings

# %%
# !pip install clearml
# Out:
# Collecting clearml
#   Downloading clearml-1.13.2-py2.py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 7.5 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=18.0 in /usr/local/lib/python3.10/dist-packages (from clearml) (23.1.0)
# Collecting furl>=2.0.0 (from clearml)
#   Downloading furl-2.1.3-py2.py3-none-any.whl (20 kB)
# Requirement already satisfied: jsonschema>=2.6.0 in /usr/local/lib/python3.10/dist-packages (from clearml) (4.19.2)
# Requirement already satisfied: numpy>=1.10 in /usr/local/lib/python3.10/dist-packages (from clearml) (1.23.5)
# Collecting pathlib2>=2.3.0 (from clearml)
#   Downloading pathlib2-2.3.7.post1-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: Pillow>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from clearml) (9.4.0)
# Requirement already satisfied: psutil>=3.4.2 in /usr/local/lib/python3.10/dist-packages (from clearml) (5.9.5)
# Requirement already satisfied: pyparsing>=2.0.3 in /usr/local/lib/python3.10/dist-packages (from clearml) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.10/dist-packages (from clearml) (2.8.2)
# Requirement already satisfied: PyYAML>=3.12 in /usr/local/lib/python3.10/dist-packages (from clearml) (6.0.1)
# Requirement already satisfied: requests>=2.20.0 in /usr/local/lib/python3.10/dist-packages (from clearml) (2.31.0)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.10/dist-packages (from clearml) (1.16.0)
# Requirement already satisfied: urllib3>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from clearml) (2.0.7)
# Collecting pyjwt<2.9.0,>=2.4.0 (from clearml)
#   Downloading PyJWT-2.8.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: referencing<0.40 in /usr/local/lib/python3.10/dist-packages (from clearml) (0.31.1)
# Collecting orderedmultidict>=1.0.1 (from furl>=2.0.0->clearml)
#   Downloading orderedmultidict-1.0.1-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6.0->clearml) (2023.11.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6.0->clearml) (0.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20.0->clearml) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20.0->clearml) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20.0->clearml) (2023.7.22)
# Installing collected packages: pyjwt, pathlib2, orderedmultidict, furl, clearml
#   Attempting uninstall: pyjwt
#     Found existing installation: PyJWT 2.3.0
#     Uninstalling PyJWT-2.3.0:
#       Successfully uninstalled PyJWT-2.3.0
# Successfully installed clearml-1.13.2 furl-2.1.3 orderedmultidict-1.0.1 pathlib2-2.3.7.post1 pyjwt-2.8.0

# %%
# !clearml-init
# Out:
# ClearML SDK setup process
#
# Please create new clearml credentials through the settings page in your `clearml-server` web app (e.g. http://localhost:8080//settings/workspace-configuration)
# Or create a free account at https://app.clear.ml/settings/workspace-configuration
#
# In settings page, press "Create new credentials", then press "Copy to clipboard".
#
# Paste copied configuration here:
# Traceback (most recent call last):
#   File "/usr/local/bin/clearml-init", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.10/dist-packages/clearml/cli/config/__main__.py", line 77, in main
# KeyboardInterrupt
# ^C

# %%
# %env CLEARML_WEB_HOST=https://app.clear.ml
# %env CLEARML_API_HOST=https://api.clear.ml
# %env CLEARML_FILES_HOST=https://files.clear.ml
# %env CLEARML_API_ACCESS_KEY=E7MAOH61Y1H2ZO7IEMTF
# %env CLEARML_API_SECRET_KEY=VhGS0ZVROhpBJRhmt19ytY0hBocY1hvaGS0tePkwgkTvmVlJGL
# Out:
# env: CLEARML_WEB_HOST=https://app.clear.ml
# env: CLEARML_API_HOST=https://api.clear.ml
# env: CLEARML_FILES_HOST=https://files.clear.ml
# env: CLEARML_API_ACCESS_KEY=E7MAOH61Y1H2ZO7IEMTF
# env: CLEARML_API_SECRET_KEY=VhGS0ZVROhpBJRhmt19ytY0hBocY1hvaGS0tePkwgkTvmVlJGL

# %% [markdown]
# # Training 1

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8s.pt data={dataset.location}/data.yaml epochs=25  lrf=0.001 lr0=0.001 batch=32 imgsz=800 plots=True
# Out:
# /content
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# yolo/engine/trainer: task=detect, mode=train, model=yolov8s.yaml, data=/content/datasets/Pistols-1645/data.yaml, epochs=25, patience=50, batch=32, imgsz=800, save=True, cache=False, device=, workers=8, project=None, name=None, exist_ok=False, pretrained=False, optimizer=SGD, verbose=True, seed=0, deterministic=True, single_cls=False, image_weights=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, overlap_mask=True, mask_ratio=4, dropout=False, val=True, save_json=False, save_hybrid=False, conf=0.001, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=ultralytics/assets/, show=False, save_txt=False, save_conf=False, save_crop=False, hide_labels=False, hide_conf=False, vid_stride=1, line_thickness=3, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=17, workspace=4, nms=False, lr0=0.001, lrf=0.001, momentum=0.937, weight_decay=0.001, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, fl_gamma=0.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, save_dir=runs/detect/train
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100% 755k/755k [00:00<00:00, 20.1MB/s]
# 2023-12-05 00:26:53.126533: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-05 00:26:53.126586: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-05 00:26:53.126644: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-05 00:26:54.482182: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.Conv                  [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.Conv                  [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.C2f                   [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.C2f                   [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.C2f                   [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.Conv                  [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.C2f                   [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.SPPF                  [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.Concat                [1]
#  12                  -1  1    591360  ultralytics.nn.modules.C2f                   [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.Concat                [1]
#  15                  -1  1    148224  ultralytics.nn.modules.C2f                   [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.Conv                  [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.Concat                [1]
#  18                  -1  1    493056  ultralytics.nn.modules.C2f                   [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.Conv                  [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.Concat                [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.C2f                   [768, 512, 1]
#  22        [15, 18, 21]  1   2116435  ultralytics.nn.modules.Detect                [1, [128, 256, 512]]
# Model summary: 225 layers, 11135987 parameters, 11135971 gradients, 28.6 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# ClearML Task: created new task id=8272f5bc530a41e281a45e3e18447083
# 2023-12-05 00:26:58,500 - clearml.Task - INFO - No repository found, storing script code instead
# ClearML results page: https://app.clear.ml/projects/9aa9aa60ac6a4896ba8d1b6c137540d5/experiments/8272f5bc530a41e281a45e3e18447083/output/log
# optimizer: SGD(lr=0.001) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.001), 63 bias
# train: Scanning /content/datasets/Pistols-1645/train/labels... 5421 images, 0 backgrounds, 0 corrupt: 100% 5421/5421 [00:02<00:00, 2299.63it/s]
# train: New cache created: /content/datasets/Pistols-1645/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/datasets/Pistols-1645/valid/labels... 506 images, 0 backgrounds, 0 corrupt: 100% 506/506 [00:00<00:00, 2460.18it/s]
# val: New cache created: /content/datasets/Pistols-1645/valid/labels.cache
# Image sizes 800 train, 800 val
# Using 2 dataloader workers
# Logging results to runs/detect/train
# Starting training for 25 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/25      11.3G      1.404      3.385      1.246         22        800: 100% 170/170 [05:14<00:00,  1.85s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00
00:00,  1.08s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:09<00:00,  1.20s/it]
#                    all        506        560      0.862      0.771      0.841      0.493
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/25      13.8G     0.5821     0.3285     0.8627         13        800: 100% 170/170 [03:05<00:00,  1.09s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:17<00:00,  2.13s/it]
#                    all        506        560       0.86       0.78      0.835      0.492
#
# 25 epochs completed in 1.882 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 22.5MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 22.5MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:16<00:00,  2.00s/it]
#                    all        506        560      0.882       0.77      0.842      0.495
# Speed: 0.3ms pre-process, 6.9ms inference, 0.0ms loss, 6.4ms post-process per image
# Results saved to runs/detect/train
# 2023-12-05 02:20:38,231 - clearml.Task - INFO - Completed model upload to https://files.clear.ml/YOLOv8/yolo.8272f5bc530a41e281a45e3e18447083/models/best.pt

# %% [markdown]
# # Training 2

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8s.pt data={dataset.location}/data.yaml epochs=50  lrf=0.001 lr0=0.001 batch=32 imgsz=800 plots=True
# Out:
# /content
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# yolo/engine/trainer: task=detect, mode=train, model=yolov8s.yaml, data=/content/datasets/Pistols-1645/data.yaml, epochs=25, patience=50, batch=32, imgsz=800, save=True, cache=False, device=, workers=8, project=None, name=None, exist_ok=False, pretrained=False, optimizer=SGD, verbose=True, seed=0, deterministic=True, single_cls=False, image_weights=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, overlap_mask=True, mask_ratio=4, dropout=False, val=True, save_json=False, save_hybrid=False, conf=0.001, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=ultralytics/assets/, show=False, save_txt=False, save_conf=False, save_crop=False, hide_labels=False, hide_conf=False, vid_stride=1, line_thickness=3, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=17, workspace=4, nms=False, lr0=0.001, lrf=0.001, momentum=0.937, weight_decay=0.001, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, fl_gamma=0.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, save_dir=runs/detect/train
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100% 755k/755k [00:00<00:00, 20.1MB/s]
# 2023-12-05 00:26:53.126533: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-05 00:26:53.126586: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-05 00:26:53.126644: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-05 00:26:54.482182: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.Conv                  [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.Conv                  [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.C2f                   [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.C2f                   [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.C2f                   [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.Conv                  [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.C2f                   [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.SPPF                  [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.Concat                [1]
#  12                  -1  1    591360  ultralytics.nn.modules.C2f                   [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.Concat                [1]
#  15                  -1  1    148224  ultralytics.nn.modules.C2f                   [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.Conv                  [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.Concat                [1]
#  18                  -1  1    493056  ultralytics.nn.modules.C2f                   [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.Conv                  [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.Concat                [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.C2f                   [768, 512, 1]
#  22        [15, 18, 21]  1   2116435  ultralytics.nn.modules.Detect                [1, [128, 256, 512]]
# Model summary: 225 layers, 11135987 parameters, 11135971 gradients, 28.6 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# ClearML Task: created new task id=8272f5bc530a41e281a45e3e18447083
# 2023-12-05 00:26:58,500 - clearml.Task - INFO - No repository found, storing script code instead
# ClearML results page: https://app.clear.ml/projects/9aa9aa60ac6a4896ba8d1b6c137540d5/experiments/8272f5bc530a41e281a45e3e18447083/output/log
# optimizer: SGD(lr=0.001) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.001), 63 bias
# train: Scanning /content/datasets/Pistols-1645/train/labels... 5421 images, 0 backgrounds, 0 corrupt: 100% 5421/5421 [00:02<00:00, 2299.63it/s]
# train: New cache created: /content/datasets/Pistols-1645/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/datasets/Pistols-1645/valid/labels... 506 images, 0 backgrounds, 0 corrupt: 100% 506/506 [00:00<00:00, 2460.18it/s]
# val: New cache created: /content/datasets/Pistols-1645/valid/labels.cache
# Image sizes 800 train, 800 val
# Using 2 dataloader workers
# Logging results to runs/detect/train
# Starting training for 25 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/25      11.3G      1.404      3.385      1.246         22        800: 100% 170/170 [05:14<00:00,  1.85s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:12<00:00,  1.51s/it]
#                    all        506        560      0.532      0.434      0.419       0.17
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/25      13.8G     0.9547     0.8732      1.032         32        800: 100% 170/170 [05:06<00:00,  1.80s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:12<00:00,  1.52s/it]
#                    all        506        560      0.653      0.535      0.559      0.272
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/25      13.8G     0.8593     0.7107     0.9799         24        800: 100% 170/170 [05:07<00:00,  1.81s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:09<00:00,  1.24s/it]
#                    all        506        560      0.761      0.573      0.665      0.335
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/25      13.8G     0.8323     0.6512     0.9617         17        800: 100% 170/170 [05:02<00:00,  1.78s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:11<00:00,  1.48s/it]
#                    all        506        560      0.726       0.65      0.701      0.355
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/25      13.8G     0.7887     0.5997      0.944         21        800: 100% 170/170 [05:04<00:00,  1.79s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:11<00:00,  1.39s/it]
#                    all        506        560      0.726      0.643      0.707      0.373
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/25      13.8G     0.7715     0.5674     0.9397         20        800: 100% 170/170 [04:58<00:00,  1.76s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:11<00:00,  1.41s/it]
#                    all        506        560      0.746      0.657      0.725       0.39
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/25      13.8G     0.7695     0.5507     0.9292         25        800: 100% 170/170 [04:59<00:00,  1.76s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:11<00:00,  1.48s/it]
#                    all        506        560       0.83      0.679      0.769      0.424
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/25      13.8G     0.7543     0.5261     0.9288         24        800: 100% 170/170 [05:03<00:00,  1.79s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:11<00:00,  1.46s/it]
#                    all        506        560      0.818      0.682      0.788      0.423
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/25      13.8G     0.7336     0.5094     0.9234         21        800: 100% 170/170 [05:08<00:00,  1.81s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:11<00:00,  1.45s/it]
#                    all        506        560      0.798      0.673      0.747      0.405
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/25      13.8G     0.7359     0.5026     0.9203         23        800: 100% 170/170 [05:07<00:00,  1.81s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:11<00:00,  1.49s/it]
#                    all        506        560      0.808      0.731      0.789      0.439
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/25      13.8G     0.7115     0.4829     0.9093         29        800: 100% 170/170 [05:08<00:00,  1.82s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:11<00:00,  1.38s/it]
#                    all        506        560      0.835      0.735      0.797       0.44
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/25      13.8G     0.6992     0.4661     0.9059         26        800: 100% 170/170 [05:08<00:00,  1.81s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:09<00:00,  1.21s/it]
#                    all        506        560      0.841      0.711        0.8      0.448
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/25      13.8G     0.6841     0.4493     0.9047         25        800: 100% 170/170 [05:08<00:00,  1.82s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:10<00:00,  1.27s/it]
#                    all        506        560      0.873      0.751      0.818      0.454
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/25      13.8G     0.6802     0.4407     0.8963         20        800: 100% 170/170 [05:06<00:00,  1.80s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:11<00:00,  1.40s/it]
#                    all        506        560      0.884      0.736      0.834      0.468
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/25      13.8G      0.674      0.432     0.8981         29        800: 100% 170/170 [05:08<00:00,  1.82s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:11<00:00,  1.43s/it]
#                    all        506        560      0.865      0.755      0.827      0.456
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/25      13.8G     0.6618     0.3971     0.8869         14        800: 100% 170/170 [03:09<00:00,  1.11s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:11<00:00,  1.47s/it]
#                    all        506        560      0.823      0.734      0.815      0.454
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/25      13.8G     0.6515     0.3849     0.8854         14        800: 100% 170/170 [03:03<00:00,  1.08s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:10<00:00,  1.28s/it]
#                    all        506        560      0.869      0.759      0.837      0.465
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/25      13.8G     0.6423      0.378     0.8756         13        800: 100% 170/170 [03:14<00:00,  1.15s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:10<00:00,  1.33s/it]
#                    all        506        560      0.866       0.75      0.829      0.476
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/25      13.8G     0.6284     0.3644     0.8766         14        800: 100% 170/170 [03:13<00:00,  1.14s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:09<00:00,  1.20s/it]
#                    all        506        560      0.879      0.745      0.819      0.481
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/25      13.8G     0.6248     0.3586     0.8728         14        800: 100% 170/170 [03:02<00:00,  1.07s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:11<00:00,  1.45s/it]
#                    all        506        560      0.858      0.774      0.846      0.489
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/25      13.8G      0.608     0.3439     0.8705         11        800: 100% 170/170 [03:04<00:00,  1.09s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:11<00:00,  1.44s/it]
#                    all        506        560      0.864      0.763      0.827      0.479
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/25      13.8G     0.6075     0.3449       0.87         12        800: 100% 170/170 [03:07<00:00,  1.10s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:11<00:00,  1.48s/it]
#                    all        506        560      0.888      0.773      0.843      0.486
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/25      13.8G     0.5987     0.3376      0.866         16        800: 100% 170/170 [03:01<00:00,  1.07s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:10<00:00,  1.36s/it]
#                    all        506        560      0.878       0.77      0.843      0.495
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/25      13.8G     0.5971      0.332     0.8647         18        800: 100% 170/170 [03:03<00:00,  1.08s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:09<00:00,  1.20s/it]
#                    all        506        560      0.862      0.771      0.841      0.493
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/25      13.8G     0.5821     0.3285     0.8627         13        800: 100% 170/170 [03:05<00:00,  1.09s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:17<00:00,  2.13s/it]
#                    all        506        560       0.86       0.78      0.835      0.492
#
# 25 epochs completed in 1.882 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 22.5MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 22.5MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:16<00:00,  2.00s/it]
#                    all        506        560      0.882       0.77      0.842      0.495
# Speed: 0.3ms pre-process, 6.9ms inference, 0.0ms loss, 6.4ms post-process per image
# Results saved to runs/detect/train
# 2023-12-05 02:20:38,231 - clearml.Task - INFO - Completed model upload to https://files.clear.ml/YOLOv8/yolo.8272f5bc530a41e281a45e3e18447083/models/best.pt

# %% [markdown]
# # Training 3

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8s.pt data={dataset.location}/data.yaml epochs=25  lrf=0.01 lr0=0.01 batch=32 imgsz=800 plots=True
# Out:
# /content
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# yolo/engine/trainer: task=detect, mode=train, model=yolov8s.yaml, data=/content/datasets/Pistols-1645/data.yaml, epochs=25, patience=50, batch=32, imgsz=800, save=True, cache=False, device=, workers=8, project=None, name=None, exist_ok=False, pretrained=False, optimizer=SGD, verbose=True, seed=0, deterministic=True, single_cls=False, image_weights=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, overlap_mask=True, mask_ratio=4, dropout=False, val=True, save_json=False, save_hybrid=False, conf=0.001, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=ultralytics/assets/, show=False, save_txt=False, save_conf=False, save_crop=False, hide_labels=False, hide_conf=False, vid_stride=1, line_thickness=3, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=17, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.001, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, fl_gamma=0.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, save_dir=runs/detect/train2
# 2023-12-05 02:21:00.005745: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-05 02:21:00.005793: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-05 02:21:00.005837: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-05 02:21:01.251389: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.Conv                  [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.Conv                  [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.C2f                   [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.C2f                   [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.C2f                   [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.Conv                  [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.C2f                   [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.SPPF                  [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.Concat                [1]
#  12                  -1  1    591360  ultralytics.nn.modules.C2f                   [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.Concat                [1]
#  15                  -1  1    148224  ultralytics.nn.modules.C2f                   [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.Conv                  [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.Concat                [1]
#  18                  -1  1    493056  ultralytics.nn.modules.C2f                   [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.Conv                  [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.Concat                [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.C2f                   [768, 512, 1]
#  22        [15, 18, 21]  1   2116435  ultralytics.nn.modules.Detect                [1, [128, 256, 512]]
# Model summary: 225 layers, 11135987 parameters, 11135971 gradients, 28.6 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# ClearML Task: created new task id=2fc6c6f30f184f6dbe0d2e71b3fba1b4
# 2023-12-05 02:21:05,042 - clearml.Task - INFO - No repository found, storing script code instead
# ClearML results page: https://app.clear.ml/projects/9aa9aa60ac6a4896ba8d1b6c137540d5/experiments/2fc6c6f30f184f6dbe0d2e71b3fba1b4/output/log
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.001), 63 bias
# train: Scanning /content/datasets/Pistols-1645/train/labels.cache... 5421 images, 0 backgrounds, 0 corrupt: 100% 5421/5421 [00:00<?, ?it/s]
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/datasets/Pistols-1645/valid/labels.cache... 506 images, 0 backgrounds, 0 corrupt: 100% 506/506 [00:00<?, ?it/s]
# Image sizes 800 train, 800 val
# Using 2 dataloader workers
# Logging results to runs/detect/train2
# Starting training for 25 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/25
0.464
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/25      13.8G     0.6282      0.384     0.8861         18        800: 100% 170/170 [03:03<00:00,  1.08s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:09<00:00,  1.23s/it]
#                    all        506        560      0.918      0.705      0.812      0.463
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/25      13.8G     0.6128     0.3692     0.8805         13        800: 100% 170/170 [03:05<00:00,  1.09s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:16<00:00,  2.08s/it]
#                    all        506        560      0.913      0.734      0.819      0.472
#
# 25 epochs completed in 1.857 hours.
# Optimizer stripped from runs/detect/train2/weights/last.pt, 22.5MB
# Optimizer stripped from runs/detect/train2/weights/best.pt, 22.5MB
#
# Validating runs/detect/train2/weights/best.pt...
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:16<00:00,  2.03s/it]
#                    all        506        560      0.912      0.734      0.819      0.472
# Speed: 0.3ms pre-process, 6.9ms inference, 0.0ms loss, 6.1ms post-process per image
# Results saved to runs/detect/train2
# 2023-12-05 04:13:11,751 - clearml.Task - INFO - Completed model upload to https://files.clear.ml/YOLOv8/yolo.2fc6c6f30f184f6dbe0d2e71b3fba1b4/models/best.pt

# %% [markdown]
# # Training 4

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8s.pt data={dataset.location}/data.yaml epochs=50  lrf=0.01 lr0=0.01 batch=16 imgsz=800 plots=True
# Out:
# /content
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# yolo/engine/trainer: task=detect, mode=train, model=yolov8s.yaml, data=/content/datasets/Pistols-1645/data.yaml, epochs=50, patience=50, batch=16, imgsz=800, save=True, cache=False, device=, workers=8, project=None, name=None, exist_ok=False, pretrained=False, optimizer=SGD, verbose=True, seed=0, deterministic=True, single_cls=False, image_weights=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, overlap_mask=True, mask_ratio=4, dropout=False, val=True, save_json=False, save_hybrid=False, conf=0.001, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=ultralytics/assets/, show=False, save_txt=False, save_conf=False, save_crop=False, hide_labels=False, hide_conf=False, vid_stride=1, line_thickness=3, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=17, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.001, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, fl_gamma=0.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, save_dir=runs/detect/train3
# 2023-12-05 04:20:47.885573: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-05 04:20:47.885635: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-05 04:20:47.885684: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-05 04:20:49.087349: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.Conv                  [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.Conv                  [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.C2f                   [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.C2f                   [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.C2f                   [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.Conv                  [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.C2f                   [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.SPPF                  [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.Concat                [1]
#  12                  -1  1    591360  ultralytics.nn.modules.C2f                   [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.Concat                [1]
#  15                  -1  1    148224  ultralytics.nn.modules.C2f                   [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.Conv                  [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.Concat                [1]
#  18                  -1  1    493056  ultralytics.nn.modules.C2f                   [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.Conv                  [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.Concat                [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.C2f                   [768, 512, 1]
#  22        [15, 18, 21]  1   2116435  ultralytics.nn.modules.Detect                [1, [128, 256, 512]]
# Model summary: 225 layers, 11135987 parameters, 11135971 gradients, 28.6 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# ClearML Task: created new task id=51f7987d37e54c58b1b117a11c90fa39
# 2023-12-05 04:20:52,426 - clearml.Task - INFO - No repository found, storing script code instead
# ClearML results page: https://app.clear.ml/projects/9aa9aa60ac6a4896ba8d1b6c137540d5/experiments/51f7987d37e54c58b1b117a11c90fa39/output/log
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.001), 63 bias
# train: Scanning /content/datasets/Pistols-1645/train/labels.cache... 5421 images, 0 backgrounds, 0 corrupt: 100% 5421/5421 [00:00<?, ?it/s]
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/datasets/Pistols-1645/valid/labels.cache... 506 images, 0 backgrounds, 0 corrupt: 100% 506/506 [00:00<?, ?it/s]
# Image sizes 800 train, 800 val
# Using 2 dataloader workers
# Logging results to runs/detect/train3
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      5.96G      1.123      1.862      1.111         18        800: 100% 339/339 [05:02<00:00,  1.12it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [00:10<00:00,  1.50it/s]
#                    all        506        560      0.595      0.493      0.536       0.25
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      7.21G     0.9626      0.845      1.012         29        800: 100% 339/339 [04:59<00:00,  1.13it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [00:10<00:00,  1.53it/s]
#                    all        506        560      0.708      0.503      0.561      0.255
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      7.21G      1.039     0.9484      1.035         23        800: 100% 339/339 [04:55<00:00,  1.15it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [00:11<00:00,  1.42it/s]
#                    all        506        560      0.579      0.442      0.462      0.205
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      7.21G      1.094      1.029      1.062         14        800: 100% 339/339 [04:54<00:00,  1.15it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [00:10<00:00,  1.47it/s]
#                    all        506        560      0.541      0.421      0.382      0.172
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      7.21G      1.095     0.9772      1.074         21        800: 100% 339/339 [04:58<00:00,  1.14it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [00:09<00:00,  1.69it/s]
#                    all        506        560      0.665       0.48      0.562      0.276
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      7.21G      1.054     0.9118      1.053         23        800: 100% 339/339 [04:56<00:00,  1.14it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [00:10<00:00,  1.50it/s]
#                    all        506        560      0.799       0.48      0.578       0.29
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      7.21G      1.022     0.8741      1.042         13        800: 100% 339/339 [04:55<00:00,  1.15it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [00:11<00:00,  1.43it/s]
#                    all        506        560      0.746      0.475      0.582      0.289
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      7.21G     0.9827     0.8238      1.023         23        800: 100% 339/339 [04:53<00:00,  1.15it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [00:10<00:00,  1.48it/s]
#                    all        506        560      0.669       0.53      0.582      0.288
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      7.21G     0.9613     0.8017      1.021         26        800: 100% 339/339 [04:52<00:00,  1.16it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [00:10<00:00,  1.48it/s]
#                    all        506        560      0.749       0.45      0.532      0.273
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      7.21G     0.9288     0.7713      1.012         15        800: 100% 339/339 [04:54<00:00,  1.15it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [00:10<00:00,  1.46it/s]
#                    all        506        560      0.745      0.578       0.65      0.336
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      7.21G     0.9274     0.7548      1.007         18        800: 100% 339/339 [04:52<00:00,  1.16it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [00:10<00:00,  1.47it/s]
#                    all        506        560        0.7       0.52      0.595      0.299
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      7.21G     0.9123     0.7254      1.001         28        800: 100% 339/339 [04:53<00:00,  1.16it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [00:10<00:00,  1.48it/s]
#                    all        506        560      0.774      0.546      0.647      0.339
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      7.21G     0.8939     0.7086     0.9966         18        800: 100% 339/339 [04:54<00:00,  1.15it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [00:10<00:00,  1.46it/s]
#                    all        506        560      0.705      0.516      0.595      0.293
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50      7.21G     0.8856     0.6993     0.9893         18        800: 100% 339/339 [04:56<00:00,  1.14it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [00:11<00:00,  1
00:00,  1.13it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [00:11<00:00,  1.38it/s]
#                    all        506        560      0.859      0.752      0.819       0.47
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      7.21G     0.6274      0.414     0.8902         27        800: 100% 339/339 [04:55<00:00,  1.15it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [00:10<00:00,  1.47it/s]
#                    all        506        560      0.886       0.76      0.825      0.478
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50      7.21G     0.6089     0.3725     0.8791         13        800: 100% 339/339 [03:05<00:00,  1.83it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [00:09<00:00,  1.69it/s]
#                    all        506        560      0.874      0.765      0.818      0.476
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      7.21G     0.5956     0.3606     0.8773         12        800: 100% 339/339 [03:01<00:00,  1.86it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [00:12<00:00,  1.26it/s]
#                    all        506        560       0.88      0.714      0.815      0.485
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      7.21G     0.5869      0.353      0.875         15        800: 100% 339/339 [03:01<00:00,  1.87it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [00:09<00:00,  1.63it/s]
#                    all        506        560      0.879      0.749      0.828      0.483
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      7.21G     0.5825     0.3435     0.8681         13        800: 100% 339/339 [03:02<00:00,  1.86it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [00:09<00:00,  1.63it/s]
#                    all        506        560      0.882      0.749      0.819      0.486
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      7.21G     0.5661     0.3352     0.8637         13        800: 100% 339/339 [03:06<00:00,  1.82it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [00:10<00:00,  1.46it/s]
#                    all        506        560      0.871      0.768      0.834      0.492
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      7.21G     0.5577     0.3291     0.8606         13        800: 100% 339/339 [03:07<00:00,  1.81it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [00:11<00:00,  1.40it/s]
#                    all        506        560      0.897      0.745      0.824      0.493
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      7.21G     0.5499     0.3157     0.8583         13        800: 100% 339/339 [03:04<00:00,  1.83it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [00:11<00:00,  1.38it/s]
#                    all        506        560      0.895      0.761      0.825      0.489
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      7.21G     0.5361     0.3098     0.8551         14        800: 100% 339/339 [03:06<00:00,  1.82it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [00:09<00:00,  1.68it/s]
#                    all        506        560      0.907      0.754      0.836      0.492
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      7.21G     0.5311     0.3012     0.8511         16        800: 100% 339/339 [03:04<00:00,  1.84it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [00:10<00:00,  1.54it/s]
#                    all        506        560      0.894      0.766      0.838      0.494
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      7.21G     0.5164     0.2926      0.848         13        800: 100% 339/339 [03:05<00:00,  1.82it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [00:15<00:00,  1.06it/s]
#                    all        506        560      0.912      0.759      0.834      0.496
#
# 50 epochs completed in 3.968 hours.
# Optimizer stripped from runs/detect/train3/weights/last.pt, 22.5MB
# Optimizer stripped from runs/detect/train3/weights/best.pt, 22.5MB
#
# Validating runs/detect/train3/weights/best.pt...
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [00:14<00:00,  1.11it/s]
#                    all        506        560      0.912      0.759      0.834      0.495
# Speed: 0.5ms pre-process, 6.8ms inference, 0.0ms loss, 4.3ms post-process per image
# Results saved to runs/detect/train3
# 2023-12-05 08:19:36,869 - clearml.Task - INFO - Completed model upload to https://files.clear.ml/YOLOv8/yolo.51f7987d37e54c58b1b117a11c90fa39/models/best.pt

# %% [markdown]
# # Training 5

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8s.pt data={dataset.location}/data.yaml epochs=50  lrf=0.001 lr0=0.001 batch=32 imgsz=800 plots=True
# Out:
# /content
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# yolo/engine/trainer: task=detect, mode=train, model=yolov8s.yaml, data=/content/datasets/Pistols-1645/data.yaml, epochs=50, patience=50, batch=16, imgsz=800, save=True, cache=False, device=, workers=8, project=None, name=None, exist_ok=False, pretrained=False, optimizer=SGD, verbose=True, seed=0, deterministic=True, single_cls=False, image_weights=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, overlap_mask=True, mask_ratio=4, dropout=False, val=True, save_json=False, save_hybrid=False, conf=0.001, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=ultralytics/assets/, show=False, save_txt=False, save_conf=False, save_crop=False, hide_labels=False, hide_conf=False, vid_stride=1, line_thickness=3, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=17, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.001, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, fl_gamma=0.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, save_dir=runs/detect/train3
# 2023-12-05 04:20:47.885573: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-05 04:20:47.885635: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-05 04:20:47.885684: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-05 04:20:49.087349: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.Conv                  [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.Conv                  [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.C2f                   [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.C2f                   [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.C2f                   [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.Conv                  [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.C2f                   [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.SPPF                  [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.Concat                [1]
#  12                  -1  1    591360  ultralytics.nn.modules.C2f                   [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.Concat                [1]
#  15                  -1  1    148224  ultralytics.nn.modules.C2f                   [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.Conv                  [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.Concat                [1]
#  18                  -1  1    493056  ultralytics.nn.modules.C2f                   [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.Conv                  [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.Concat                [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.C2f                   [768, 512, 1]
#  22        [15, 18, 21]  1   2116435  ultralytics.nn.modules.Detect                [1, [128, 256, 512]]
# Model summary: 225 layers, 11135987 parameters, 11135971 gradients, 28.6 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# ClearML Task: created new task id=51f7987d37e54c58b1b117a11c90fa39
# 2023-12-05 04:20:52,426 - clearml.Task - INFO - No repository found, storing script code instead
# ClearML results page: https://app.clear.ml/projects/9aa9aa60ac6a4896ba8d1b6c137540d5/experiments/51f7987d37e54c58b1b117a11c90fa39/output/log
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.001), 63 bias
# train: Scanning /content/datasets/Pistols-1645/train/labels.cache... 5421 images, 0 backgrounds, 0 corrupt: 100% 5421/5421 [00:00<?, ?it/s]
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/datasets/Pistols-1645/valid/labels.cache... 506 images, 0 backgrounds, 0 corrupt: 100% 506/506 [00:00<?, ?it/s]
# Image sizes 800 train, 800 val
# Using 2 dataloader workers
# Logging results to runs/detect/train3
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      5.96G      1.123      1.862      1.111         18        800: 100% 339/339 [05:02<00:00,  1.12it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [00:10<00:00,  1.50it/s]
#                    all        506        560      0.595      0.493      0.536       0.25
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      7.21G     0.9626      0.845      1.012         29        800: 100% 339/339 [04:59<00:00,  1.13it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [00:10<00:00,  1.53it/s]
#                    all        506        560      0.708      0.503      0.561      0.255
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      7.21G      1.039     0.9484      1.035         23        800: 100% 339/339 [04:55<00:00,  1.15it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [00:11<00:00,  1.42it/s]
#                    all        506        560      0.579      0.442      0.462      0.205
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      7.21G      1.094      1.029      1.062         14        800: 100% 339/339 [04:54<00:00,  1.15it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [00:10<00:00,  1.47it/s]
#                    all        506        560      0.541      0.421      0.382      0.172
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      7
00:00,  1.14it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [00:09<00:00,  1.73it/s]
#                    all        506        560      0.838      0.704      0.776      0.436
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50      7.21G     0.7214      0.502     0.9245         21        800: 100% 339/339 [04:55<00:00,  1.15it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [00:10<00:00,  1.59it/s]
#                    all        506        560      0.854      0.699       0.79      0.436
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50      7.21G     0.7092     0.4829     0.9226         29        800: 100% 339/339 [04:53<00:00,  1.16it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [00:10<00:00,  1.49it/s]
#                    all        506        560      0.884      0.705      0.806       0.45
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50      7.21G     0.7089     0.4885     0.9166         21        800: 100% 339/339 [04:55<00:00,  1.15it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [00:11<00:00,  1.44it/s]
#                    all        506        560      0.864       0.74      0.814      0.455
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50      7.21G     0.6858     0.4659     0.9136         21        800: 100% 339/339 [04:54<00:00,  1.15it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [00:10<00:00,  1.47it/s]
#                    all        506        560      0.845      0.716      0.807      0.452
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50      7.21G     0.6778     0.4585     0.9133         17        800: 100% 339/339 [04:52<00:00,  1.16it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [00:11<00:00,  1.42it/s]
#                    all        506        560      0.827      0.734      0.799      0.455
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50      7.21G     0.6709     0.4582     0.9053         34        800: 100% 339/339 [04:59<00:00,  1.13it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [00:09<00:00,  1.65it/s]
#                    all        506        560      0.865      0.709      0.796      0.454
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50      7.21G     0.6697      0.441      0.905         24        800: 100% 339/339 [04:59<00:00,  1.13it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [00:10<00:00,  1.46it/s]
#                    all        506        560      0.828      0.781      0.812       0.46
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50      7.21G     0.6556     0.4412     0.8992         24        800: 100% 339/339 [04:56<00:00,  1.14it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [00:11<00:00,  1.41it/s]
#                    all        506        560      0.837      0.746      0.817      0.454
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50      7.21G     0.6507     0.4236     0.8978         22        800: 100% 339/339 [04:56<00:00,  1.14it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [00:11<00:00,  1.40it/s]
#                    all        506        560       0.87      0.738      0.822      0.479
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50      7.21G     0.6425     0.4286     0.8962         15        800: 100% 339/339 [04:58<00:00,  1.13it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [00:11<00:00,  1.38it/s]
#                    all        506        560      0.859      0.752      0.819       0.47
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      7.21G     0.6274      0.414     0.8902         27        800: 100% 339/339 [04:55<00:00,  1.15it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [00:10<00:00,  1.47it/s]
#                    all        506        560      0.886       0.76      0.825      0.478
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50      7.21G     0.6089     0.3725     0.8791         13        800: 100% 339/339 [03:05<00:00,  1.83it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [00:09<00:00,  1.69it/s]
#                    all        506        560      0.874      0.765      0.818      0.476
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      7.21G     0.5956     0.3606     0.8773         12        800: 100% 339/339 [03:01<00:00,  1.86it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [00:12<00:00,  1.26it/s]
#                    all        506        560       0.88      0.714      0.815      0.485
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      7.21G     0.5869      0.353      0.875         15        800: 100% 339/339 [03:01<00:00,  1.87it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [00:09<00:00,  1.63it/s]
#                    all        506        560      0.879      0.749      0.828      0.483
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      7.21G     0.5825     0.3435     0.8681         13        800: 100% 339/339 [03:02<00:00,  1.86it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [00:09<00:00,  1.63it/s]
#                    all        506        560      0.882      0.749      0.819      0.486
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      7.21G     0.5661     0.3352     0.8637         13        800: 100% 339/339 [03:06<00:00,  1.82it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [00:10<00:00,  1.46it/s]
#                    all        506        560      0.871      0.768      0.834      0.492
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      7.21G     0.5577     0.3291     0.8606         13        800: 100% 339/339 [03:07<00:00,  1.81it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [00:11<00:00,  1.40it/s]
#                    all        506        560      0.897      0.745      0.824      0.493
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      7.21G     0.5499     0.3157     0.8583         13        800: 100% 339/339 [03:04<00:00,  1.83it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [00:11<00:00,  1.38it/s]
#                    all        506        560      0.895      0.761      0.825      0.489
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      7.21G     0.5361     0.3098     0.8551         14        800: 100% 339/339 [03:06<00:00,  1.82it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [00:09<00:00,  1.68it/s]
#                    all        506        560      0.907      0.754      0.836      0.492
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      7.21G     0.5311     0.3012     0.8511         16        800: 100% 339/339 [03:04<00:00,  1.84it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [00:10<00:00,  1.54it/s]
#                    all        506        560      0.894      0.766      0.838      0.494
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      7.21G     0.5164     0.2926      0.848         13        800: 100% 339/339 [03:05<00:00,  1.82it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [00:15<00:00,  1.06it/s]
#                    all        506        560      0.912      0.759      0.834      0.496
#
# 50 epochs completed in 3.968 hours.
# Optimizer stripped from runs/detect/train3/weights/last.pt, 22.5MB
# Optimizer stripped from runs/detect/train3/weights/best.pt, 22.5MB
#
# Validating runs/detect/train3/weights/best.pt...
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [00:14<00:00,  1.11it/s]
#                    all        506        560      0.912      0.759      0.834      0.495
# Speed: 0.5ms pre-process, 6.8ms inference, 0.0ms loss, 4.3ms post-process per image
# Results saved to runs/detect/train3
# 2023-12-05 08:19:36,869 - clearml.Task - INFO - Completed model upload to https://files.clear.ml/YOLOv8/yolo.51f7987d37e54c58b1b117a11c90fa39/models/best.pt

# %%
# Vizualise the runs directory content
# !ls {HOME}/runs/detect/train5/
# Out:
# args.yaml					     results.png	    val_batch0_pred.jpg
# confusion_matrix.png				     train_batch0.jpg	    val_batch1_labels.jpg
# events.out.tfevents.1701384826.0f1cd8b44d44.12078.0  train_batch1.jpg	    val_batch1_pred.jpg
# F1_curve.png					     train_batch2.jpg	    val_batch2_labels.jpg
# P_curve.png					     train_batch5085.jpg    val_batch2_pred.jpg
# PR_curve.png					     train_batch5086.jpg    weights
# R_curve.png					     train_batch5087.jpg
# results.csv					     val_batch0_labels.jpg

# %%
# confusion matrix for the last training
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train5/confusion_matrix.png', width=600)
# Out:
# /content

# %%
# Evaluation metrics (not needed as clearML provide more optmized vizualisations)
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train5/results.png', width=600)
# Out:
# /content

# %%
# Vizualise the validation batch (promising results)
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train4/val_batch0_pred.jpg', width=600)
# Out:
# /content

# %% [markdown]
# ## Validate Custom Model

# %%
# %cd {HOME}

# !yolo task=detect mode=val model={HOME}/runs/detect/train4/weights/best.pt data={dataset.location}/data.yaml
# Out:
# /content
# 2023-12-01 04:56:40.542582: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-01 04:56:40.542650: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-01 04:56:40.542691: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-01 04:56:42.296612: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /content/datasets/Pistols-1645/valid/labels.cache... 506 images, 0 backgrounds, 0 corrupt: 100% 506/506 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 32/32 [00:12<00:00,  2.50it/s]
#                    all        506        560       0.91      0.754      0.834      0.495
# Speed: 1.4ms pre-process, 13.2ms inference, 0.0ms loss, 2.1ms post-process per image

# %%
import shutil
import os
from google.colab import files

folder_path = '/content/runs/detect/train5/weights'
zip_file_path = '/content/weights2'

# Create a zip file for downloading the training content
shutil.make_archive(zip_file_path[:-4], 'zip', folder_path)
# Out:
# '/content/weig.zip'

# %% [markdown]
# Inference with Custom Model yolov8s on unseen data using the best weight, after comparing the models and picking the best one.

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model={HOME}/best.pt conf=0.25 source=/content/test save=True
# Out:
# /content
# 2023-12-07 13:43:58.399295: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-07 13:43:58.399365: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-07 13:43:58.399434: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-07 13:43:59.399502: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
# image 1/6 /content/test/1.jpg: 480x800 3 pistols, 67.9ms
# image 2/6 /content/test/2.jpg: 448x800 1 pistol, 58.7ms
# image 3/6 /content/test/3.jpg: 480x800 2 pistols, 16.1ms
# image 4/6 /content/test/4.jpeg: 544x800 6 pistols, 74.7ms
# image 5/6 /content/test/5.jpg: 384x800 1 pistol, 72.4ms
# image 6/6 /content/test/6.jpg: 544x800 1 pistol, 18.2ms
# Speed: 0.5ms pre-process, 51.3ms inference, 53.7ms postprocess per image at shape (1, 3, 800, 800)
# Results saved to runs/detect/predict

# %% [markdown]
# Now Let's take a look at few results, we will test our model on a unseen data to monitor the capacity of detecting in images that was not seen and unexpcted context.

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'{HOME}/runs/detect/predict/*.jpg'):
      display(Image(filename=image_path, width=600))
      print("\n")

# %%
print("hello")
# Out:
# hello

# %%
from ultralytics import YOLO

model = YOLO("best.pt")  # load a pretrained model (recommended for training)
success = model.export(format="onnx")  # export the model to ONNX format
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
#
# PyTorch: starting from best.pt with output shape (1, 5, 13125) (21.5 MB)
# requirements: YOLOv8 requirement "onnx>=1.12.0" not found, attempting AutoUpdate...
# Collecting onnx>=1.12.0
#   Downloading onnx-1.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (15.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 88.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from onnx>=1.12.0) (1.23.5)
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.10/dist-packages (from onnx>=1.12.0) (3.20.3)
# Installing collected packages: onnx
# Successfully installed onnx-1.15.0
#
# requirements: 1 package updated per ['onnx>=1.12.0']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.15.0...
# ONNX: export success ✅ 9.5s, saved as best.onnx (42.7 MB)
#
# Export complete (24.8s)
# Results saved to /content
# Predict:         yolo task=detect mode=predict model=best.onnx -WARNING ⚠️ not yet supported for YOLOv8 exported models
# Validate:        yolo task=detect mode=val model=best.onnx -WARNING ⚠️ not yet supported for YOLOv8 exported models
# Visualize:       https://netron.app
